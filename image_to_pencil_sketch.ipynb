# %% [markdown]
# <a href="https://colab.research.google.com/github/kallurudayanadeepthi/LGMVIP_DATASCIENCE/blob/main/image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image=cv2.imread('/pic.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x531 at 0x7F2213304C50>

# %%
#grey scale image
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x7F2212128FD0>

# %%
#inverted scale image
inverted_image = cv2.bitwise_not(grey_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x7F221213E510>

# %%
#image smoothing
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x7F221213AB50>

# %%
#pencil sketch
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)
pencil_sketch=pencil_sketch(grey_image,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x7F221213EB90>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=800x531 at 0x7F2212128990>
# <PIL.Image.Image image mode=L size=800x531 at 0x7F2212128150>
